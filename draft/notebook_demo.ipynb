# %%
USE MurachCollege;
GO
# Out:
# Commands completed successfully.

# %%
/*   4   */
SELECT 
    DepartmentName,
    CourseDescription, 
    LastName,
    FirstName
FROM Departments AS d
JOIN Courses AS c ON d.DepartmentID = c.DepartmentID
JOIN StudentCourses AS sc ON sc.CourseID = c.CourseID
JOIN Students AS s ON s.StudentID = sc.StudentID
WHERE d.DepartmentName = 'English'
ORDER BY CourseDescription ASC;
# Out:
# (15 rows affected)
# DepartmentName | CourseDescription  | LastName | FirstName
# ---------------+--------------------+----------+----------
# English        | Classic Literature | Morrisey | Monica
# English        | Classic Literature | Jackson  | Floyd
# English        | Classic Literature | Gardner  | Faye
# English        | Classic Literature | George   | Mona
# English        | Classic Literature | Biden    | Jonas
# English        | Composition        | Manning  | Vincent
# English        | Composition        | Johnson  | Timothy
# English        | Creative Writing   | Taylor   | Donna
# English        | Creative Writing   | Goodell  | Conner
# English        | Creative Writing   | Griffin  | Gerald
# English        | Creative Writing   | Biden    | Jonas
# English        | Shakespeare        | Williams | Bonnie
# English        | Shakespeare        | Camden   | James
# English        | Shakespeare        | Jones    | Andrew
# English        | Shakespeare        | Goodell  | Conner
# (15 rows)

# %%
/*   9   */
SELECT 
    LastName,
    FirstName,
    EnrollmentDate, 
    GraduationDate
FROM Students
WHERE EnrollmentDate > '12-01-2022' AND GraduationDate is NULL
# Out:
# (5 rows affected)
# LastName | FirstName | EnrollmentDate      | GraduationDate
# ---------+-----------+---------------------+---------------
# Cramsden | Walter    | 2022-12-15 10:18:37 | NULL
# Lisle    | Lisa      | 2022-12-17 11:42:28 | NULL
# George   | Mona      | 2022-12-22 15:29:44 | NULL
# Silver   | Stanley   | 2023-01-04 11:16:19 | NULL
# Biden    | Jonas     | 2023-01-05 13:47:21 | NULL
# (5 rows)

# %%
/*   10   */
SELECT
    FullTimeCost,
    PerUnitCost,
    12 AS Units,
    PerUnitCost * 12 AS TotalPerUnitCost,
    FullTimeCost + (PerUnitCost * 12) AS TotalTuition
FROM
    Tuition;
# Out:
# (1 row affected)
# FullTimeCost | PerUnitCost | Units | TotalPerUnitCost | TotalTuition
# -------------+-------------+-------+------------------+-------------
# 1250.00      | 62.50       | 12    | 750.00           | 2000.00
# (1 row)
